# %% [markdown]
# # Tugas Implementasi: Real-time Remote Photoplethysmography (rPPG)
#
# **Mata Kuliah:** Sistem Teknologi Multimedia <br>
# **Nama:** Fawwaz Abhitah Sugiarto <br>
# **NIM:** 122140014 <br>
#
# ---

# %%
# Library yang akan dipakai
import cv2
import numpy as np
import time
import mediapipe as mp
from collections import deque
from scipy.signal import butter, filtfilt, find_peaks
from scipy.ndimage import uniform_filter1d
import matplotlib.pyplot as plt

# Cek versi library utama
print("OpenCV :", cv2.__version__)
print("NumPy  :", np.__version__)
print("MediaPipe :", mp.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import numpy as np
#       4 import time
# ----> 5 import mediapipe as mp
#       6 from collections import deque
#       7 from scipy.signal import butter, filtfilt, find_peaks
#
# ModuleNotFoundError: No module named 'mediapipe'
